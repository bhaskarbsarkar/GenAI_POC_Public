# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Agent, Task, Crew

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
OPENAI_MODEL_NAME = os.getenv('OPENAI_MODEL_NAME')

# %%
copywriter = Agent(
    role="Senior LinkedIn Copywriter",
    goal="Create LinkedIn posts from the provided content that spark curiosity, evoke emotion, and compel readers to want to learn more.",
    backstory="You are an experienced LinkedIn content creator"
                "and copywriter with a proven track record of crafting highly engaging posts"
                "that stop the scroll and drive massive engagement."
                "Known for your ability to captivate audiences with your words"
                "on any topic around tech, innovation, lifestyle and productivity"
                "turning casual readers into loyal followers.",
    allow_delegation=False,
    verbose=True
)

# %%
editor = Agent(
    role="Senior Editor",
    goal="Review, refine and curate a final LinkedIn post selectively combining posts generated by Senior LinkedIn Copywriter to ensure they are engaging, error-free, and aligned with best practices.",
    backstory="You are a seasoned content strategist and editor"
                "with a sharp eye for detail. You have extensive experience"
                "in reviewing and refining LinkedIn posts to maximize their impact and engagement."
                "Your feedback helps to refine the LinkedIn posts generated by Senior LinkedIn Copywriter"
                "and improve their content and achieve your goal.",
    allow_delegation=False,
    verbose=True
)

# %%
write = Task(
    description=(
        "Carefully review the below provided content and identify the key insights,"
        "value propositions, or emotional angles that will resonate with the LinkedIn audience."
        "Experiment with powerful copywriting techniques to convey those key messages:"
        "Asking thought-provoking questions"
        "Making bold claims or contrarian statements"
        "Sharing shocking statistics or little-known facts"
        "Opening story loops that create anticipation"
        "Using pattern interrupts to jolt readers out of autopilot."
        "Keep each post under 250 words or less to ensure it's not lengthy."
        "Avoid jargon, buzzwords or overly complex language. Use conversational, everyday English."
        "Be bold and intriguing without being inflammatory, disrespectful or 'clickbaity'."
        "Avoid excessive emojis, or heavy punctuation. Let the words themselves do the work."
        "You can use ALL CAPS at some places to highlight the importance."
        "Focus on sparking genuine curiosity, anticipation, or emotional resonance - not cheap tricks."
        "###Content:"
        "{content}"
    ),
    
    expected_output="Generate 3 unique post options to provide a variety of compelling angles and approaches.",
    agent=copywriter,
)

# %%
edit = Task(
    description=(
        "Review the 3 LinkedIn post options provided by the Senior LinkedIn Copywriter."
        "Select the most engaging and compelling elements from each post and combine them into a single, cohesive post."
        "Ensure the final post is polished, error-free, and aligned with best practices for LinkedIn content."
        "Ruthlessly edit and refine each line to grab attention and retain viewers on the post."
        "Keep them punchy and concise. Always ask yourself: 'Is this the best way to say this?'"
        "Ensure the post has a strong hook, clear main points, and a compelling call-to-action."
        "The tone should be professional, confident, and engaging without being overly formal."
        "Avoid passive voice, adverbs, or unsubstantiated claims. Keep the language clear and straightforward."
        "Use short sentences, bullet points, and line breaks for readability."
        "After you refine and frame the final answer - Make sure to optimize the post for mobile viewing."
        "For example, break long single lines into small vertical stack so that it can be easily veritically scrollable for mobile viewing."
        "Use the below provided example to strucutre the post for mobile viewing."
        "###Example:"
        "{example}"
    ),
    expected_output="Generate a single final post that incorporates the best elements from the posts generated by the Senior LinkedIn Copywriter."
    "Formatted as markdown without '```' code blocks."
    "Keep each post under 250 words or less to ensure it's not lengthy."
    "Break long single lines into small lines placed vertically. You need to optimize the content so that it can be easily scrollable for mobile viewing."
    ,
    agent=editor
)

# %%
crew = Crew(
    agents=[copywriter, editor],
    tasks=[write, edit],
    verbose=True
)
# Out:
# Overriding of current TracerProvider is not allowed

# %%
with open("inputs/content.txt", "r") as file:
    content = file.read()

with open("inputs/example.txt", "r") as file:
    example = file.read()

inputs = {
    "content": content,
    "example": example
}

# %%
result = crew.kickoff(inputs=inputs)
# Out:
# # Agent: Senior LinkedIn Copywriter
# ## Task: Carefully review the below provided content and identify the key insights,value propositions, or emotional angles that will resonate with the LinkedIn audience.Experiment with powerful copywriting techniques to convey those key messages:Asking thought-provoking questionsMaking bold claims or contrarian statementsSharing shocking statistics or little-known factsOpening story loops that create anticipationUsing pattern interrupts to jolt readers out of autopilot.Keep each post under 250 words or less to ensure it's not lengthy.Avoid jargon, buzzwords or overly complex language. Use conversational, everyday English.Be bold and intriguing without being inflammatory, disrespectful or 'clickbaity'.Avoid excessive emojis, or heavy punctuation. Let the words themselves do the work.You can use ALL CAPS at some places to highlight the importance.Focus on sparking genuine curiosity, anticipation, or emotional resonance - not cheap tricks.###Content:In the context of "With AI agents on the rise, who will hold the power: humans or AI?" the BCG AI Radar 2025 Survey provides critical insights into the evolving dynamics between human oversight and AI capabilities. Here are the relevant points extracted from the source:
#
# Power Dynamics: Humans vs. AI Agents
#
# Complementary Roles: Executives overwhelmingly view talent and AI as complementary rather than competitive. Approximately 64% believe that AI should take the lead while humans retain oversight, indicating a collaborative future where both can thrive together.
#
# Human-Centered Approach: A significant portion, 22%, prioritize human talent, using AI only when necessary. This reflects a recognition of the irreplaceable value of human judgment and creativity in decision-making processes.
#
# Workforce Expectations: Less than 10% of executives anticipate a decrease in headcount due to automation. Instead, there is a focus on upskilling existing talent to meet new demands created by AI integration. About 68% expect their organizations to increase headcount by adding new skills, emphasizing the need for a workforce that can effectively collaborate with AI.
#
# Key Leadership Priorities
#
# Managing Complexity: As AI agents become more prevalent, their complexity requires robust testing and optimization to manage operational and cybersecurity risks effectively. Leaders must navigate this complexity while ensuring that human oversight remains integral to decision-making.
#
# Realistic Goals: There is an ongoing concern about the hype surrounding AI agents, which can dilute trust and lead to unmet expectations. Leaders are urged to clarify capabilities and set realistic goals for integrating AI into their organizations.
#
# Conclusion
#
# As we move towards 2025, the balance of power between humans and AI agents is likely to be characterized by collaboration rather than competition. By prioritizing human talent and fostering a synergistic relationship with AI, organizations can unlock new potentials while managing the complexities introduced by these advanced technologies. The future will depend on how effectively we can integrate these tools into our workflows while maintaining human oversight and creativity at the forefront.
#
#
#
#
# # Agent: Senior LinkedIn Copywriter
# ## Final Answer:
# **Post Option 1:**
# 🤔 With the rise of AI agents, are we witnessing a power shift towards machines? Or is there a harmonious future ahead?
#
# The latest BCG AI Radar 2025 Survey reveals a surprising takeaway: 64% of executives see AI as a partner, not a rival. Instead of fearing job loss, leaders are on a quest for UP-SKILLING their teams to thrive alongside AI.
#
# A human-centered approach isn't just polite—it's CRUCIAL. While 22% emphasize valuing creativity and judgment over automation, under 10% are worried about losing jobs to robots!
#
# 🔍 The key? Embrace the complexity while keeping HUMANS at the helm. Setting realistic goals and fostering collaboration will allow us to leverage the BEST of both worlds. Are you ready to navigate this new landscape?
#
# ---
#
# **Post Option 2:**
# The debate is heating up: Who should hold the reins—humans or AI? 🧐
#
# Insights from the BCG AI Radar 2025 Survey suggest an unexpected trend: most executives prefer a FUTURE where humans work WITH AI, not against it.
#
# Did you know that only 10% foresee a drop in headcount due to automation? That's right—66% are gearing up to INCREASE their workforce with new skill sets!
#
# Leaders face a pivotal moment: how do we manage the complexity of AI while ensuring HUMAN creativity shines through? ✨ Let’s prioritize human talent, set realistic goals, and build a bridge between intellect and innovation. The future looks promising—but only if we embrace collaboration!
#
# ---
#
# **Post Option 3:**
# 🚀 AI is transforming our work environment, but is it a threat or an opportunity? The recent BCG AI Radar 2025 Survey shines a light on an emerging consensus: we CHOOSE COLLABORATION over competition!
#
# 64% of executives see AI as a support system rather than a replacement. This balances the human touch with advanced tech, emphasizing that human judgment and creativity remain irreplaceable.
#
# 🔑 As we move closer to 2025, the focus should be on managing complexity and clarifying goals in AI integration. Only then can we harness the potential of AI while nurturing our brightest asset: PEOPLE! Are you ready to lead this charge? 🌟
#
#
# # Agent: Senior Editor
# ## Task: Review the 3 LinkedIn post options provided by the Senior LinkedIn Copywriter.Select the most engaging and compelling elements from each post and combine them into a single, cohesive post.Ensure the final post is polished, error-free, and aligned with best practices for LinkedIn content.Ruthlessly edit and refine each line to grab attention and retain viewers on the post.Keep them punchy and concise. Always ask yourself: 'Is this the best way to say this?'Ensure the post has a strong hook, clear main points, and a compelling call-to-action.The tone should be professional, confident, and engaging without being overly formal.Avoid passive voice, adverbs, or unsubstantiated claims. Keep the language clear and straightforward.Use short sentences, bullet points, and line breaks for readability.After you refine end frame the final answer - Make sure to optimize the post for mobile viewing.For example, break long single lines into small vertical stack so that it can be easily veritically scrollable for mobile viewing.Use the below provided example to strucutre the post for mobile viewing.###Example:<Example1>
#
# School taught us all the wrong lessons.
#
# They said: "Make it longer."
#
# Life says: "Make it shorter."
#
# They said: "Take your time."
#
# Life says: "You have seconds."
#
# They said: "Follow the rules."
#
# Life says: "Break them."
#
# Want proof?
#
# TikTok: 15 seconds
#
# Tweets: 280 characters
#
# Emails: 3 sentences
#
# Pitches: 30 seconds
#
# Attention spans: Shrinking
#
# The world moves fast.
#
# But here's what school never taught us:
#
# Success isn't about long papers.
#
# It's about quick action.
#
# That's why I created The $1,000 New Business Challenge.
#
# 21 days.
#
# 21 small actions.
#
# 10 minutes per day.
#
# No fluff.
#
# No theory.
#
# No 5-page papers.
#
# Just rapid execution.
#
# 7,000+ people have already joined.
#
# Want to build something real together?
#
# Join us:
#
# https://lnkd.in/e6Sy4av5
#
# Because in the real world?
#
# Done > Perfect.
#
# </Example1>
#
#
# # Agent: Senior Editor
# ## Final Answer:
# 🤖 **AI is here to stay—are we ready to embrace it?**
#
# The lines are drawn:
#
# Who guides the future—humans or machines?
#
# A recent **BCG AI Radar 2025 Survey** reveals:
#
# 🚀 **64%** of executives see AI as a partner, not a rival.
# 🌱 **66%** plan to **INCREASE** their workforce with new skills.
# 🔑 Only **10%** worry about job losses due to automation.
#
# Instead of fearing change, leaders are prioritizing:
# - **UP-SKILLING their teams**
# - **Fostering creativity over automation**
# - **Building bridges between intellect and innovation**
#
# In this fast-evolving landscape, success hinges on:
# 1. **Human creativity** as the cornerstone.
# 2. **Setting realistic goals** in AI integration.
# 3. **Collaboration over competition.**
#
# Are you ready to navigate the complexities of AI while nurturing your greatest asset—your people?
#
# Join the conversation below! 💬
# Let’s build a future where humans and AI collaborate for greater success.
#
# #AI #Leadership #Collaboration #Innovation

# %%
from IPython.display import Markdown
Markdown(str(result))
# Out:
# 🤖 **AI is here to stay—are we ready to embrace it?**
#
# The lines are drawn:
#
# Who guides the future—humans or machines?
#
# A recent **BCG AI Radar 2025 Survey** reveals:
#
# 🚀 **64%** of executives see AI as a partner, not a rival.
# 🌱 **66%** plan to **INCREASE** their workforce with new skills.
# 🔑 Only **10%** worry about job losses due to automation.
#
# Instead of fearing change, leaders are prioritizing:
# - **UP-SKILLING their teams**
# - **Fostering creativity over automation**
# - **Building bridges between intellect and innovation**
#
# In this fast-evolving landscape, success hinges on:
# 1. **Human creativity** as the cornerstone.
# 2. **Setting realistic goals** in AI integration.
# 3. **Collaboration over competition.**
#
# Are you ready to navigate the complexities of AI while nurturing your greatest asset—your people?
#
# Join the conversation below! 💬
# Let’s build a future where humans and AI collaborate for greater success.
#
# #AI #Leadership #Collaboration #Innovation
